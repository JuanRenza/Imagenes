# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanRenza/Imagenes/blob/master/Clase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Importo las librerias necesarias

import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

#Grafico imagenes estaticas en el notebook

# %matplotlib inline

#Leo y muestro una imagen 

image = cv2.imread('/content/drive/My Drive/colab/Imagenes/prueba.png')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=410x230 at 0x7FDAEBE56860>

# %%
#Comando para saber el directorio actual
# !pwd 
#Comando para saber los archivos de la ruta
# !ls
#Comando para cambiar directorio al de imagenes en drive (Va con % porque tiene espacios)
# %cd /content/drive/My Drive/colab/Imagenes

#Leo la imagen, le cambio el tamaño y la muestro
img = cv2.imread('prueba.png')
img = cv2.resize(img, (int(820),int(460))) #Duplico el tamaño
cv2_imshow(img)
# Out:
# /content/drive/My Drive/colab/Imagenes
# prueba.png
# /content/drive/My Drive/colab/Imagenes
# <PIL.Image.Image image mode=RGB size=820x460 at 0x7FDAEBE5FDA0>

# %%
#Importo librerias del sistema
import os

#Creo una nueva ruta para importar archivos
path = '/content/drive/My Drive/colab/Imagenes'

#Cambio el directorio con la función chdir de os

os.chdir(path)
# !pwd

#Leo la imagen, creo una figura y muestro la imagen dentro de la figura creada
img = cv2.imread('prueba.png', cv2.IMREAD_COLOR)

plt.figure(figsize=(17,7))
plt.imshow(img)
plt.show()
# Out:
# /content/drive/My Drive/colab/Imagenes
